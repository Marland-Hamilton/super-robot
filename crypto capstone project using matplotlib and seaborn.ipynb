# %% [markdown]
# # CAPSTONE PROJECT

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. import packages 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
c_invest_df = pd.read_csv('crypto_daily_prices.csv')
c_returns_df = pd.read_csv('crypto_daily_returns.csv')

# %%
c_invest_df.head()
# Out:
#         Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0  9/17/2014     457.334015            NaN        5.05855
# 1  9/18/2014     424.440002            NaN        4.68523
# 2  9/19/2014     394.795990            NaN        4.32777
# 3  9/20/2014     408.903992            NaN        4.28644
# 4  9/21/2014     398.821014            NaN        4.24592

# %%
c_returns_df.head()
# Out:
#         Date       BTC  ETH       LTC
# 0  9/17/2014  0.000000  0.0  0.000000
# 1  9/18/2014 -7.192558  NaN -7.379983
# 2  9/19/2014 -6.984264  NaN -7.629499
# 3  9/20/2014  3.573492  NaN -0.955003
# 4  9/21/2014 -2.465854  NaN -0.945300

# %%
# 2. Displays BTC crypto daily prices on a single figure.
c_invest_df.plot(x='Date', y='BTC-USD Price',label='BTC Daily Price', figsize=(15,10),linewidth=4)
plt.xlabel('Date')
plt.ylabel('Price [$]')
plt.title('BTC')
plt.grid()

# %%
# 3. Displays crypto daily prices on multiple subplots.
plt.figure(figsize=(15,10))
plt.subplot(1,3,1)
plt.plot(c_invest_df['BTC-USD Price'],'blue',label='BTC')
plt.title('BTC Daily price')


plt.subplot(1,3,2)
plt.plot(c_invest_df['ETH-USD Price'],'green',label='ETH')
plt.title('ETH Daily Price')



plt.subplot(1,3,3)
plt.plot(c_invest_df['LTC-USD Price'],'red',label='LTC')
plt.title('LTC Daily Price')
# Out:
# Text(0.5, 1.0, 'LTC Daily Price')

# %%
# 3.B display daily crypto in a single slot.

c_invest_df.plot(x='Date',y=['BTC-USD Price','ETH-USD Price','LTC-USD Price'],figsize=(15,10),linewidth=3)
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
# 4. displays scatter plot between Bitcoin and Ethereum.
x=c_returns_df['BTC'] 
y=c_returns_df['ETH']
plt.figure(figsize=(10,15))
plt.scatter(x,y)
plt.grid()

# %%
# 5. plotting using seaborn, displaying Bitcoin vs Ethereum.
sns.scatterplot(x='BTC', y='ETH', data = c_returns_df)
# Out:
# <AxesSubplot: xlabel='BTC', ylabel='ETH'>

# %%
# 6.displaying pie chart that shows 50% BTC and 25% for ETH and LTC.
values  = [50, 25, 25,]
colors  = ['b', 'g', 'r']
explode = [0.1, 0.1, 0.1]
labels  = ['BTC', 'ETH', 'LTC']


plt.figure(figsize= (10,10))
plt.pie(values, colors= colors , labels= labels,explode= explode)
plt.title('Crypto Portfolio')
# Out:
# Text(0.5, 1.0, 'Crypto Portfolio')

# %%
# 7. displayiing histgram that shows ETH returns.

mu = daily_return_df['FB'].mean() # mean of distribution
sigma = daily_return_df['FB'].std() # standard deviation of distribution
 
num_bins = 30

plt.figure(figsize = (15,9))
plt.hist(c_returns_df['ETH'],num_bins, facecolor ='red')
plt.grid()
plt.title('Histogram: mu = ' + str(mu) +' sigma =' + str(sigma))
# Out:
# Text(0.5, 1.0, 'Histogram: mu = 0.12914075422941618 sigma =2.0337648345424886')

# %%
# 8. Heatmap that show correnlations between crypto daily returns.

# %%
plt.figure(figsize=(30,30))
sns.heatmap(c_returns_df.corr(),annot = True)
# Out:
# <AxesSubplot: >
